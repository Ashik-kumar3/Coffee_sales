# %%
import matplotlib.pyplot as plt

# %%
expn=[2000,300,1000,5000,4000,1000]
label=['crnt_bill','recharge','ptrl','food','rent','other']

# %%
plt.pie(expn,labels=label,radius=1.1,autopct="%1.1f%%",shadow=True,colors=['y','b','r','white','orange','pink'])
plt.title('Monthly Expenses')
plt.show()

# %%
import pandas as pd

# %%
df=pd.read_csv('employe.csv',sep=';')
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.shape
# Out:
# (4653, 9)

# %%
df[df['Education']=='Bachelors'].count()
# Out:
# Education                    3601
# JoiningYear                  3601
# City                         3601
# PaymentTier                  3601
# Age                          3601
# Gender                       3601
# EverBenched                  3601
# ExperienceInCurrentDomain    3601
# LeaveOrNot                   3601
# dtype: int64

# %%
a=df[(df['Education']=='Bachelors')].groupby('JoiningYear').count()['Education']
a
# Out:
# JoiningYear
# 2012    441
# 2013    531
# 2014    605
# 2015    640
# 2016    461
# 2017    660
# 2018    263
# Name: Education, dtype: int64

# %%
label=df['JoiningYear'].unique()
label.sort()

# %%
plt.pie(a,labels=label,autopct='%1.1f%%')
plt.title('Bachelors Joining Year')
plt.show()

# %% [markdown]
# BOX PLOT
# -

# %% [markdown]
# To visualize distribution of the data.
#
# Also known as box-and-whisker plot.

# %% [markdown]
# Box plot components

# %% [markdown]
# Median
#
# lower quartile
#
# Upper quartile
#
# whisker
#
# Interquartile range(IQR)
#
# Outliers.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# STEPS TO PLOT BOX PLOT
# ----------------------
# -Median of data is calculated.
#
# -First quartile and third quartile is calculated.
#
# -IQR = Thirdquartile - firstquartile.
#
# -The IQR(Interquartile Range) is a measure of statistical dispersion.It's essentially the range of the middle %0% of the data.
#
# -Step3 : Calculate the lower whisker as max(First quartile - 1.5 * IQR,minimum value in dataset).
#
# -Step4 : Calculate the upper whisker as max(Third quartile - 1.5 * IQR,minimum value in dataset).

# %% [markdown]
# Median: The median is the middle value of a dataset when it's sorted in ascending order. In a box plot, it's represented by the line inside the box.
#
# First Quartile (Q1) and Third Quartile (Q3): These values divide the dataset into four equal parts. Q1 is the median of the lower half of the data, and Q3 is the median of the upper half.
#
# Interquartile Range (IQR): It's the range between Q3 and Q1, calculated as IQR = Q3 - Q1. It represents the spread of the middle 50% of the data.
#
# Lower Whisker: The lower whisker typically extends to the smallest data point within 1.5 times the IQR below the Q1. If there are no data points below this value, the lower whisker extends to the minimum value in the dataset.
#
# Upper Whisker: The upper whisker extends to the largest data point within 1.5 times the IQR above the Q3. If there are no data points above this value, the upper whisker extends to the maximum value in the dataset.
#
# Outliers: Data points beyond the whiskers are considered outliers and are plotted individually as points. They fall outside the range of the whiskers.
#
# To create a box plot using Matplotlib:
#
# Step 1: Calculate the median, Q1, and Q3 of your dataset.
#
# Step 2: Compute the IQR using IQR = Q3 - Q1.
#
# Step 3: Calculate the lower whisker as max(First quartile - 1.5 * IQR, minimum value in dataset).
#
# Step 4: Calculate the upper whisker as min(Third quartile + 1.5 * IQR, maximum value in dataset).

# %%
df=pd.read_csv('employe.csv',sep=';')
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
plt.boxplot(df['Age'],patch_artist=True,showmeans=True)
plt.title('Age distribution')
plt.show()

# %%
qrtl1=df['Age'].quantile(0.25)
qrtl3=df['Age'].quantile(0.75)

# %%
qrtl1
# Out:
# np.float64(26.0)

# %%
qrtl3
# Out:
# np.float64(32.0)

# %%
IQR = qrtl3 - qrtl1
IQR
# Out:
# np.float64(6.0)

# %%
lower_whisker = max(qrtl1 - 1.5*IQR,df['Age'].min())
lower_whisker
# Out:
# np.int64(22)

# %%
upper_whisker = min(qrtl3 + 1.5*IQR,df['Age'].max())
upper_whisker
# Out:
# np.float64(41.0)

# %%
df=pd.read_csv("Copy of diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
plt.boxplot(df['Glucose'],patch_artist=True,showmeans=True)
plt.title('Glucose')
plt.show()

# %%
df['Glucose'].min()
# Out:
# np.int64(0)

# %%
qrtl1=df['Glucose'].quantile(0.25)
qrtl3=df['Glucose'].quantile(0.75)

# %%
qrtl1
# Out:
# np.float64(99.0)

# %%
qrtl3
# Out:
# np.float64(140.25)

# %%
IQR=qrtl3-qrtl1
IQR
# Out:
# np.float64(41.25)

# %%
lw = max(qrtl1 - 1.5*IQR,df['Glucose'].min())
lw
# Out:
# np.float64(37.125)

# %%
uw = min(qrtl3 + 1.5*IQR,df['Glucose'].max())
uw
# Out:
# np.int64(199)

# %%
out = df[(df['Glucose']<lw) | (df['Glucose']>uw)]
out
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 182            1        0             74             20       23  27.7
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
df1 = df[(df['Glucose']>lw) & (df['Glucose']<uw)]
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [762 rows x 9 columns]

# %%
plt.boxplot(df1['Glucose'],patch_artist=True,showmeans=True)
plt.title('Glucose')
plt.show()
