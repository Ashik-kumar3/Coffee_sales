# %%
import pandas as pd
df=pd.read_csv('coffe_sales.csv',sep=',')
df.head()
# Out:
#    hour_of_day cash_type  money    coffee_name Time_of_Day Weekday Month_name  \
# 0           10      card   38.7          Latte     Morning     Fri        Mar
# 1           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 2           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 3           13      card   28.9      Americano   Afternoon     Fri        Mar
# 4           13      card   38.7          Latte   Afternoon     Fri        Mar
#
#    Weekdaysort  Monthsort        Date             Time
# 0            5          3  2024-03-01  10:15:50.520000
# 1            5          3  2024-03-01  12:19:22.539000
# 2            5          3  2024-03-01  12:20:18.089000
# 3            5          3  2024-03-01  13:46:33.006000
# 4            5          3  2024-03-01  13:48:14.626000

# %%
df.isna().sum()
# Out:
# hour_of_day    0
# cash_type      0
# money          0
# coffee_name    0
# Time_of_Day    0
# Weekday        0
# Month_name     0
# Weekdaysort    0
# Monthsort      0
# Date           0
# Time           0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
df['Month_name'].sort_values()
# Out:
# 215     Apr
# 269     Apr
# 268     Apr
# 267     Apr
# 266     Apr
#        ...
# 1427    Sep
# 1426    Sep
# 1425    Sep
# 1433    Sep
# 1621    Sep
# Name: Month_name, Length: 3547, dtype: str

# %%
import matplotlib.pyplot as plt
df['coffee_name'].unique()
# Out:
# <StringArray>
# [              'Latte',       'Hot Chocolate',           'Americano',
#  'Americano with Milk',               'Cocoa',             'Cortado',
#             'Espresso',          'Cappuccino']
# Length: 8, dtype: str

# %%
Time=df.groupby('Time_of_Day').size()
Time
# Out:
# Time_of_Day
# Afternoon    1205
# Morning      1181
# Night        1161
# dtype: int64

# %%
Count=df.groupby('coffee_name').size()
plt.plot(Count,c='g',marker='o',markerfacecolor='b',markersize=5,linewidth=2)
plt.xlabel('Coffeename')
plt.ylabel('Sales')
plt.xticks(rotation=90)
plt.grid(c='r')
plt.show()

# %% [markdown]
# Conclusion :- The Americano with Milk has more demand while the Espresso has the least.So,making more 'Americano with Milk' coffee will become benefit to increase the sales amount.

# %%
Month=df.groupby('Month_name').size()
plt.plot(Month,c='g',marker='o',markerfacecolor='b',markersize=5,linewidth=2)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=90)
plt.grid(c='r')
plt.show()

# %%
fig, axs = plt.subplots(2,2,figsize=(10,10))

Coffee=df.groupby('coffee_name').size()
Time=df.groupby('Time_of_Day').size()
Month=df.groupby('Monthsort').size().sort_index()
Weekday=df.groupby('Weekday').size()


axs[0,0].barh(Coffee.index,Coffee.values,color='g')
axs[0,0].set_xlabel('Count')
axs[0,0].set_ylabel('Coffee Name')
axs[0,0].set_title('Coffee Name')
axs[0,0].tick_params(rotation=28)
# axs[0,0].set_grid(c='r')
# axs[0,0].show()

axs[0,1].bar(Time.index,Time.values,color='g',linewidth=2,width=0.5)
axs[0,1].set_xlabel('Time')
axs[0,1].set_ylabel('Sales')
# axs[0,1].xticks(rotation=90)
# axs[0,1].grid(c='r')
# axs[0,1].show()

axs[1,0].plot(Month,c='g',marker='o',markerfacecolor='b',markersize=5,linewidth=2)
axs[1,0].set_xlabel('Time')
axs[1,0].set_ylabel('Sales')
# axs[1,0].xticks(rotation=90)
# axs[1,0].grid(c='r')
# axs[1,0].show()

axs[1,1].plot(Weekday,c='g',marker='o',markerfacecolor='b',markersize=5,linewidth=2)
axs[1,1].set_xlabel('Time')
axs[1,1].set_ylabel('Sales')
# axs[1,1].xticks(rotation=90)
# axs[1,1].grid(c='r')
# axs[1,1].show()
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.bar(df['coffee_name'],df['Money'],label='coffee',color='b',width=.5)
plt.legend()
plt.xlabel('Money')
plt.ylabel('Count')
plt.xticks
plt.title('Coffee_name and Count')
plt.show()

# %%
plt.plot(df['coffee_name'],df[''],c='g',marker='o',markerfacecolor='b',markersize=5,linewidth=2)
plt.xlabel('BP')
plt.ylabel('Glucose')
plt.grid(c='r')
plt.show()

# %%
fig, axs = plt.subplots(2,2,figsize=(10,10))

axs[0,0].hist(df['coffee_name'],color='y',rwidth=0.5,bins=5)
axs[0,0].set_title('coffee_name')
axs[0,0].set_xlabel('Time')
axs[0,0].set_ylabel('Count')

axs[0,1].hist(df['Time_of_Day'],color='g')
axs[0,1].set_title('Time')
axs[0,1].set_xlabel('Time')
axs[0,1].set_ylabel('Count')

axs[1,0].hist(df['Weekday'],bins=5,color='r',rwidth=0.5)
axs[1,0].set_title('Weekday')
axs[1,0].set_xlabel('Week')
axs[1,0].set_ylabel('Count')

axs[1,1].hist(df['Month_name'],color='k',rwidth=0.5)
axs[1,1].set_title('Month')
axs[1,1].set_xlabel('Month')
axs[1,1].set_ylabel('Count')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 6
#       4 axs[0,0].set_title('coffee_name')
#       5 axs[0,0].set_xlabel('Time')
# ----> 6 axs[0,0].xticks(rotation=90)
#       7 axs[0,0].set_ylabel('Count')
#       9 axs[0,1].hist(df['Time_of_Day'],color='g')
#
# AttributeError: 'Axes' object has no attribute 'xticks'

# %%
plt.plot(df['coffee_name'],df['Weekday'],c='g',marker='o',markerfacecolor='b',markersize=5,linewidth=2)
plt.xlabel('BP')
plt.ylabel('Glucose')
plt.grid(c='r')
plt.show()

# %%
growth=df[(df['coffee_name'])&(df['Time_of_Day'])].groupby('Weekday')
growth
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 growth=df[(df['coffee_name'])&(df['Time_of_Day'])].groupby('Weekday')
#       2 growth
#
# File c:\Users\HP\Desktop\AI\Matplotlib\env\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\HP\Desktop\AI\Matplotlib\env\Lib\site-packages\pandas\core\arraylike.py:72, in OpsMixin.__and__(self, other)
#      70 @unpack_zerodim_and_defer("__and__")
#      71 def __and__(self, other):
# ---> 72     return self._logical_method(other, operator.and_)
#
# File c:\Users\HP\Desktop\AI\Matplotlib\env\Lib\site-packages\pandas\core\series.py:6746, in Series._logical_method(self, other, op)
# ...
